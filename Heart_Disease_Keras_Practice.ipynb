# %%
# !pip install keras
# !pip install tensorflow
# !pip install sklearn
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

import numpy as np
from random import randint
from sklearn.preprocessing import MinMaxScaler
# Out:
# Requirement already satisfied: keras in c:\users\kpradhan\anaconda3\lib\site-packages (2.4.3)
# Requirement already satisfied: h5py in c:\users\kpradhan\anaconda3\lib\site-packages (from keras) (3.1.0)
# Requirement already satisfied: pyyaml in c:\users\kpradhan\anaconda3\lib\site-packages (from keras) (5.4.1)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\kpradhan\anaconda3\lib\site-packages (from keras) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in c:\users\kpradhan\anaconda3\lib\site-packages (from keras) (1.6.2)
# Requirement already satisfied: tensorflow in c:\users\kpradhan\anaconda3\lib\site-packages (2.5.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: grpcio~=1.34.0 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (1.34.1)
# Requirement already satisfied: tensorboard~=2.5 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: gast==0.4.0 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (2.5.0.dev2021032900)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: six~=1.15.0 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (0.36.2)
# Requirement already satisfied: absl-py~=0.10 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (0.13.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (0.4.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (1.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (2.25.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (1.34.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (52.0.0.post20210125)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\kpradhan\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kpradhan\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\kpradhan\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kpradhan\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\kpradhan\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\kpradhan\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kpradhan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\kpradhan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\kpradhan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kpradhan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (1.26.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\kpradhan\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow) (3.1.1)
# Requirement already satisfied: sklearn in c:\users\kpradhan\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\kpradhan\anaconda3\lib\site-packages (from sklearn) (0.24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kpradhan\anaconda3\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\kpradhan\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\kpradhan\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.19.5)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\kpradhan\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.6.2)

# %%
train_sample = []
train_label = []

for i in range(1000):
    younger_ages = randint(13, 64)
    train_sample.append(younger_ages)
    train_label.append(0)
    
    older_ages = randint(65, 100)
    train_sample.append(older_ages)
    train_label.append(1)

train_sample
# Out:
# [57,
#  76,
#  58,
#  79,
#  41,
#  95,
#  51,
#  75,
#  41,
#  78,
#  52,
#  85,
#  17,
#  87,
#  53,
#  70,
#  48,
#  96,
#  42,
#  69,
#  64,
#  73,
#  39,
#  85,
#  15,
#  91,
#  23,
#  76,
#  53,
#  71,
#  36,
#  70,
#  60,
#  92,
#  57,
#  96,
#  49,
#  72,
#  17,
#  78,
#  27,
#  75,
#  19,
#  90,
#  29,
#  73,
#  37,
#  81,
#  27,
#  68,
#  33,
#  97,
#  23,
#  95,
#  24,
#  79,
#  20,
#  85,
#  63,
#  83,
#  28,
#  97,
#  26,
#  99,
#  26,
#  94,
#  42,
#  69,
#  62,
#  96,
#  38,
#  81,
#  32,
#  88,
#  27,
#  97,
#  37,
#  91,
#  15,
#  73,
#  60,
#  76,
#  33,
#  65,
#  18,
#  100,
#  45,
#  73,
#  64,
#  90,
#  41,
#  77,
#  54,
#  73,
#  64,
#  98,
#  15,
#  84,
#  33,
#  92,
#  18,
#  94,
#  31,
#  78,
#  64,
#  81,
#  57,
#  79,
#  38,
#  97,
#  31,
#  91,
#  26,
#  73,
#  32,
#  74,
#  64,
#  65,
#  44,
#  94,
#  60,
#  92,
#  46,
#  95,
#  16,
#  87,
#  34,
#  98,
#  15,
#  66,
#  27,
#  83,
#  54,
#  65,
#  60,
#  93,
#  25,
#  80,
#  35,
#  93,
#  22,
#  90,
#  16,
#  80,
#  41,
#  73,
#  33,
#  96,
#  61,
#  80,
#  26,
#  95,
#  24,
#  68,
#  49,
#  88,
#  33,
#  93,
#  44,
#  93,
#  16,
#  70,
#  31,
#  67,
#  37,
#  67,
#  25,
#  99,
#  26,
#  78,
#  40,
#  89,
#  13,
#  66,
#  27,
#  89,
#  35,
#  71,
#  62,
#  77,
#  32,
#  85,
#  36,
#  97,
#  24,
#  83,
#  51,
#  75,
#  53,
#  88,
#  55,
#  96,
#  45,
#  84,
#  14,
#  91,
#  38,
#  70,
#  57,
#  70,
#  39,
#  88,
#  57,
#  79,
#  15,
#  67,
#  36,
#  66,
#  27,
#  90,
#  40,
#  98,
#  18,
#  66,
#  41,
#  100,
#  49,
#  86,
#  37,
#  71,
#  33,
#  85,
#  30,
#  66,
#  19,
#  93,
#  36,
#  68,
#  15,
#  80,
#  26,
#  90,
#  57,
#  76,
#  46,
#  69,
#  28,
#  98,
#  47,
#  99,
#  22,
#  89,
#  63,
#  89,
#  50,
#  65,
#  41,
#  74,
#  49,
#  92,
#  17,
#  70,
#  38,
#  90,
#  29,
#  84,
#  17,
#  100,
#  44,
#  70,
#  62,
#  75,
#  13,
#  79,
#  25,
#  85,
#  26,
#  88,
#  37,
#  77,
#  38,
#  65,
#  27,
#  84,
#  22,
#  82,
#  58,
#  94,
#  19,
#  83,
#  57,
#  70,
#  64,
#  87,
#  58,
#  90,
#  25,
#  86,
#  56,
#  93,
#  15,
#  65,
#  17,
#  74,
#  16,
#  77,
#  48,
#  96,
#  62,
#  84,
#  51,
#  91,
#  49,
#  81,
#  39,
#  96,
#  29,
#  89,
#  40,
#  86,
#  56,
#  96,
#  15,
#  75,
#  31,
#  71,
#  27,
#  98,
#  22,
#  77,
#  29,
#  92,
#  51,
#  98,
#  17,
#  65,
#  38,
#  94,
#  24,
#  78,
#  22,
#  78,
#  46,
#  85,
#  34,
#  84,
#  44,
#  91,
#  57,
#  80,
#  45,
#  77,
#  26,
#  67,
#  40,
#  98,
#  23,
#  99,
#  28,
#  95,
#  27,
#  87,
#  42,
#  85,
#  27,
#  87,
#  24,
#  94,
#  61,
#  73,
#  52,
#  96,
#  45,
#  71,
#  42,
#  92,
#  64,
#  71,
#  60,
#  82,
#  47,
#  89,
#  51,
#  90,
#  27,
#  84,
#  43,
#  70,
#  19,
#  89,
#  32,
#  85,
#  52,
#  75,
#  38,
#  82,
#  58,
#  67,
#  54,
#  71,
#  14,
#  67,
#  32,
#  73,
#  64,
#  98,
#  20,
#  70,
#  22,
#  88,
#  40,
#  78,
#  22,
#  87,
#  53,
#  65,
#  61,
#  94,
#  46,
#  86,
#  20,
#  69,
#  38,
#  96,
#  23,
#  66,
#  33,
#  88,
#  54,
#  82,
#  42,
#  91,
#  43,
#  77,
#  22,
#  77,
#  36,
#  67,
#  56,
#  88,
#  24,
#  73,
#  46,
#  74,
#  54,
#  95,
#  48,
#  82,
#  16,
#  72,
#  46,
#  100,
#  41,
#  77,
#  45,
#  90,
#  22,
#  95,
#  17,
#  83,
#  25,
#  95,
#  33,
#  84,
#  63,
#  94,
#  16,
#  97,
#  13,
#  73,
#  41,
#  80,
#  30,
#  96,
#  13,
#  72,
#  31,
#  78,
#  21,
#  98,
#  62,
#  82,
#  30,
#  80,
#  29,
#  78,
#  38,
#  83,
#  42,
#  100,
#  17,
#  67,
#  20,
#  95,
#  50,
#  88,
#  51,
#  96,
#  20,
#  100,
#  29,
#  74,
#  41,
#  65,
#  40,
#  65,
#  46,
#  66,
#  61,
#  86,
#  29,
#  86,
#  35,
#  70,
#  58,
#  81,
#  28,
#  83,
#  14,
#  94,
#  59,
#  83,
#  59,
#  97,
#  46,
#  66,
#  55,
#  75,
#  29,
#  91,
#  36,
#  67,
#  39,
#  73,
#  29,
#  85,
#  62,
#  67,
#  44,
#  95,
#  38,
#  87,
#  54,
#  87,
#  57,
#  69,
#  29,
#  78,
#  23,
#  73,
#  38,
#  92,
#  25,
#  69,
#  45,
#  85,
#  64,
#  74,
#  57,
#  95,
#  59,
#  90,
#  34,
#  73,
#  20,
#  84,
#  58,
#  71,
#  59,
#  83,
#  33,
#  73,
#  30,
#  85,
#  48,
#  98,
#  20,
#  68,
#  40,
#  70,
#  37,
#  95,
#  63,
#  66,
#  44,
#  93,
#  28,
#  86,
#  51,
#  75,
#  64,
#  98,
#  35,
#  66,
#  55,
#  92,
#  45,
#  88,
#  55,
#  92,
#  41,
#  75,
#  58,
#  73,
#  30,
#  79,
#  39,
#  85,
#  49,
#  86,
#  18,
#  65,
#  49,
#  96,
#  47,
#  76,
#  42,
#  81,
#  23,
#  65,
#  45,
#  87,
#  28,
#  81,
#  35,
#  91,
#  55,
#  72,
#  42,
#  96,
#  18,
#  72,
#  18,
#  66,
#  25,
#  70,
#  19,
#  68,
#  30,
#  83,
#  32,
#  86,
#  50,
#  80,
#  16,
#  94,
#  62,
#  85,
#  46,
#  71,
#  48,
#  66,
#  61,
#  92,
#  54,
#  66,
#  36,
#  69,
#  22,
#  95,
#  57,
#  77,
#  38,
#  88,
#  23,
#  66,
#  61,
#  92,
#  13,
#  92,
#  13,
#  76,
#  54,
#  67,
#  23,
#  89,
#  14,
#  90,
#  45,
#  76,
#  60,
#  87,
#  25,
#  68,
#  49,
#  65,
#  48,
#  74,
#  59,
#  79,
#  64,
#  66,
#  45,
#  76,
#  30,
#  71,
#  44,
#  93,
#  46,
#  78,
#  57,
#  99,
#  57,
#  97,
#  26,
#  80,
#  55,
#  67,
#  22,
#  81,
#  18,
#  68,
#  60,
#  99,
#  54,
#  84,
#  40,
#  84,
#  58,
#  82,
#  54,
#  86,
#  35,
#  77,
#  27,
#  94,
#  22,
#  90,
#  41,
#  72,
#  60,
#  96,
#  49,
#  79,
#  43,
#  72,
#  21,
#  81,
#  38,
#  97,
#  55,
#  89,
#  64,
#  86,
#  32,
#  77,
#  61,
#  97,
#  41,
#  96,
#  43,
#  89,
#  34,
#  96,
#  15,
#  87,
#  31,
#  100,
#  17,
#  67,
#  46,
#  75,
#  63,
#  92,
#  49,
#  88,
#  55,
#  89,
#  45,
#  74,
#  52,
#  67,
#  64,
#  83,
#  30,
#  73,
#  24,
#  85,
#  24,
#  98,
#  55,
#  88,
#  18,
#  87,
#  51,
#  90,
#  54,
#  67,
#  20,
#  71,
#  31,
#  90,
#  30,
#  72,
#  25,
#  93,
#  56,
#  94,
#  21,
#  93,
#  44,
#  82,
#  29,
#  77,
#  35,
#  72,
#  32,
#  97,
#  22,
#  65,
#  43,
#  99,
#  37,
#  92,
#  57,
#  93,
#  35,
#  65,
#  43,
#  78,
#  61,
#  89,
#  20,
#  89,
#  62,
#  94,
#  54,
#  71,
#  59,
#  81,
#  16,
#  75,
#  18,
#  77,
#  47,
#  99,
#  37,
#  67,
#  18,
#  83,
#  62,
#  94,
#  48,
#  69,
#  19,
#  93,
#  38,
#  90,
#  51,
#  86,
#  61,
#  79,
#  48,
#  73,
#  22,
#  76,
#  48,
#  83,
#  33,
#  80,
#  64,
#  96,
#  22,
#  71,
#  53,
#  95,
#  38,
#  92,
#  47,
#  66,
#  24,
#  79,
#  13,
#  86,
#  29,
#  87,
#  22,
#  66,
#  17,
#  88,
#  53,
#  67,
#  31,
#  75,
#  19,
#  82,
#  13,
#  80,
#  58,
#  97,
#  50,
#  93,
#  26,
#  75,
#  24,
#  67,
#  57,
#  97,
#  58,
#  76,
#  18,
#  77,
#  52,
#  90,
#  14,
#  95,
#  49,
#  75,
#  62,
#  65,
#  47,
#  88,
#  51,
#  67,
#  31,
#  96,
#  59,
#  87,
#  32,
#  67,
#  16,
#  80,
#  31,
#  91,
#  23,
#  97,
#  47,
#  72,
#  51,
#  98,
#  14,
#  68,
#  27,
#  100,
#  62,
#  95,
#  22,
#  86,
#  24,
#  94,
#  42,
#  90,
#  19,
#  91,
#  64,
#  99,
#  60,
#  86,
#  15,
#  71,
#  22,
#  70,
#  43,
#  71,
#  37,
#  74,
#  14,
#  73,
#  46,
#  83,
#  39,
#  68,
#  59,
#  88,
#  39,
#  86,
#  28,
#  69,
#  23,
#  68,
#  64,
#  93,
#  36,
#  66,
#  35,
#  95,
#  25,
#  80,
#  64,
#  69,
#  41,
#  68,
#  53,
#  79,
#  62,
#  97,
#  30,
#  90,
#  61,
#  77,
#  29,
#  83,
#  28,
#  67,
#  62,
#  72,
#  46,
#  72,
#  20,
#  89,
#  24,
#  78,
#  38,
#  91,
#  58,
#  97,
#  43,
#  79,
#  62,
#  99,
#  ...]

# %%
train_sample = np.array(train_sample)
train_label =  np.array(train_label)

# %%
scalar = MinMaxScaler(feature_range = (0,1))
scalar_train_sample = scalar.fit_transform(train_sample.reshape(-1,1))

# %%
model = Sequential([Dense(16, input_dim=1, activation='relu'), Dense(32, activation = 'relu'), Dense(2, activation='softmax')])
model.compile(Adam(lr=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(train_sample,train_label,batch_size=10,epochs=10)
# Out:
# Epoch 1/10
# 200/200 [==============================] - 13s 1ms/step - loss: 1.0031 - accuracy: 0.5430
# Epoch 2/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5318 - accuracy: 0.7500: 0s - loss: 0.5692 - accuracy
# Epoch 3/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4147 - accuracy: 0.8487
# Epoch 4/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3372 - accuracy: 0.8988
# Epoch 5/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2844 - accuracy: 0.9025
# Epoch 6/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2408 - accuracy: 0.9315
# Epoch 7/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2091 - accuracy: 0.9344
# Epoch 8/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1866 - accuracy: 0.9318
# Epoch 9/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2131 - accuracy: 0.9015
# Epoch 10/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1597 - accuracy: 0.9458

# %%
test_sample = []
test_label = [] 

for i in range(500):
    younger_ages = randint(13, 64)
    test_sample.append(younger_ages)
    test_label.append(0)
    
    older_ages = randint(65, 100)
    test_sample.append(older_ages)
    test_label.append(1)
    
test_sample = np.array(test_sample)
test_label =  np.array(test_label)

test_sample_output = model.predict(test_sample, batch_size=10)
